# %%
from supreme import verificacao_supreme
from supreme import calcular_fatorial

# %%
print("hello world")
# Out:
# hello world

# %%
verificacao = verificacao_supreme()
print(verificacao)
# Out:
# REDIRECIONANDO....SUUUUUUUUUUUUPREEEEEEEEEEEEEEMEEEEEEEEEEEEEEEE
# True

# %%
if verificacao:
    print("Usuário Permitido!")
else:
    print("Usuário Negado!")
# Out:
# Usuário Permitido!

# %%
# Teste rápido
numero = 5
print(f"O fatorial de {numero} é {calcular_fatorial(numero)}")
# Out:
# O fatorial de 5 é 120
